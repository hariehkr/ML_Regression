# %%
import zipfile
import sys, os
from pathlib import Path
sys.path.append(str(Path(__file__).resolve().parents[1])) # Modify the path dynamically
from dataclasses import dataclass
from pathlib import Path
from src.datascience.constants import *
from src.datascience.utils.common import read_yaml, create_directories

import os
import urllib.request as request
from src.datascience import  logger
2+5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 import zipfile
#       2 import sys, os
#       3 from pathlib import Path
# ----> 4 sys.path.append(str(Path(__file__).resolve().parents[1])) # Modify the path dynamically
#       5 from dataclasses import dataclass
#       6 from pathlib import Path
#       7 from src.datascience.constants import *
#
# NameError: name '__file__' is not defined

# %%
@dataclass
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path
print('excuted')
# Out:
# excuted

# %%
class ConfigurationManager:
    def __init__(self,
                 config_filepath= CONFIG_FILE_PATH,
                 params_filepath = PARAMS_FILE_PATH,
                 schema_filepath = SCHEMA_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion
        create_directories([self.config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=self.config.root_dir,
            source_URL=self.config.source_URL,
            local_data_file=self.config.local_data_file,
            unzip_dir=self.config.unzip_dir,
        )
        return data_ingestion_config
print('excuted')
# Out:
# excuted

# %%
## component_Data Ingestion
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config

    # downloading the zip file
    def download_file(self):
        if not os.path.exists(self.config.local_data_file):
            filename, headers = request.urlretrieve(url=self.config.source_URL,
                                                    filename=self.config.local_data_file)
            logger.info(f"Downloaded file {filename} file with following info:\n {headers}")
        else:
            logger.info(f"File  already exists")

    def extract_zip_file(self):
        """
        zip_file_path : str
        extracts the zip file into the data directory
        function returns None
        """
        unzip_dir = self.config.unzip_dir
        os.makedirs(unzip_dir, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_dir)

# %%
config = ConfigurationManager()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 config = ConfigurationManager()
#
# Cell In[3], line 6, in ConfigurationManager.__init__(self, config_filepath, params_filepath, schema_filepath)
#       2     def __init__(self,
#       3                  config_filepath= CONFIG_FILE_PATH,
#       4                  params_filepath = PARAMS_FILE_PATH,
#       5                  schema_filepath = SCHEMA_FILE_PATH):
# ----> 6         self.config = read_yaml(config_filepath)
#       7         self.params = read_yaml(params_filepath)
#       8         self.schema = read_yaml(schema_filepath)
#       9
#
# File ~/projects/ML_Regression/venv/lib/python3.12/site-packages/ensure/main.py:872, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
#     870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
# --> 872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#     874     msg = "Return value of {f} of type {valt} " "does not match annotation type {t}"
#
# File ~/projects/ML_Regression/src/datascience/utils/common.py:32, in read_yaml(path_to_yaml)
#      30     raise ValueError("yaml file is empty")
#      31 except Exception as e:
# ---> 32     raise e
#
# File ~/projects/ML_Regression/src/datascience/utils/common.py:25, in read_yaml(path_to_yaml)
#      12 """reads yaml file and returns
#      13
#      14 Args:
#    (...)     22     ConfigBox: ConfigBox type
#      23 """
#      24 try:
# ---> 25     with open(path_to_yaml) as yaml_file:
#      26         content = yaml.safe_load(yaml_file)
#      27         logger.info(f"yaml file: {path_to_yaml} loaded sucessfully")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config/config.yaml'

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()

except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 9
#       5     data_ingestion.download_file()
#       6     data_ingestion.extract_zip_file()
#       7
#       8 except Exception as e:
# ----> 9     raise e
#
# Cell In[5], line 9
#       5     data_ingestion.download_file()
#       6     data_ingestion.extract_zip_file()
#       7
#       8 except Exception as e:
# ----> 9     raise e
#
# Cell In[3], line 6, in ConfigurationManager.__init__(self, config_filepath, params_filepath, schema_filepath)
#       2     def __init__(self,
#       3                  config_filepath= CONFIG_FILE_PATH,
#       4                  params_filepath = PARAMS_FILE_PATH,
#       5                  schema_filepath = SCHEMA_FILE_PATH):
# ----> 6         self.config = read_yaml(config_filepath)
#       7         self.params = read_yaml(params_filepath)
#       8         self.schema = read_yaml(schema_filepath)
#       9
#
# File ~/projects/ML_Regression/venv/lib/python3.12/site-packages/ensure/main.py:872, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
#     870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
# --> 872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#     874     msg = "Return value of {f} of type {valt} " "does not match annotation type {t}"
#
# File ~/projects/ML_Regression/src/datascience/utils/common.py:32, in read_yaml(path_to_yaml)
#      30     raise ValueError("yaml file is empty")
#      31 except Exception as e:
# ---> 32     raise e
#
# File ~/projects/ML_Regression/src/datascience/utils/common.py:25, in read_yaml(path_to_yaml)
#      12 """reads yaml file and returns
#      13
#      14 Args:
#    (...)     22     ConfigBox: ConfigBox type
#      23 """
#      24 try:
# ---> 25     with open(path_to_yaml) as yaml_file:
#      26         content = yaml.safe_load(yaml_file)
#      27         logger.info(f"yaml file: {path_to_yaml} loaded sucessfully")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config/config.yaml'
